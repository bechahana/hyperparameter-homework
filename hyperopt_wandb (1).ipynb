# %% [markdown]
# # Copyright
#
# <PRE>
# This notebook was created as part of the "Deep learning / VITMMA19" class at
# Budapest University of Technology and Economics, Hungary,
# https://portal.vik.bme.hu/kepzes/targyak/VITMMA19
#
# Any re-use or publication of any part of the notebook is only allowed with the
#  written consent of the authors.
#
# 2025 (c) Mohammed Salah Al-Radhi and Tamás Gábor Csapó (malradhi@tmit.bme.hu)
# </PRE>

# %%
### HYPEROPT: task during the class - we will do this together
# add WandB.ai integration to the code
# (help: https://docs.wandb.ai/guides/integrations/lightning )
# run at least 3 different trainings

# %%
# install pytorch lithening

# !pip install pytorch-lightning --quiet
# !pip install wandb --quiet

# %%
import pytorch_lightning as pl
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader,random_split
from torchmetrics import Accuracy
from torchvision import transforms
from torchvision.datasets import CIFAR10
from pytorch_lightning.loggers import WandbLogger
import wandb

# %%
# create one class to deal with data
class CifarDataModule(pl.LightningDataModule):
  def __init__(self, batch_size, data_dir="./"):
    super().__init__()
    self.data_dir=data_dir
    self.batch_size=batch_size
    self.transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))])
    self.num_classes=10

  def prepare_data(self):
    CIFAR10(self.data_dir,train=True,download=True)
    CIFAR10(self.data_dir,train=False,download=True)

  def setup(self, stage=None):
    if stage=='fit' or stage is None:
      cifar_full=CIFAR10(self.data_dir,train=True,transform=self.transform)
      self.cifar_train,self.cifar_val=random_split(cifar_full,[45000,5000])

    if stage=='test' or stage is None:
      self.cifar_test=CIFAR10(self.data_dir,train=False,transform=self.transform)

  def train_dataloader(self):
    return DataLoader(self.cifar_train,batch_size=self.batch_size,shuffle=True,num_workers=2)

  def val_dataloader(self):
    return DataLoader(self.cifar_val,batch_size=self.batch_size,shuffle=False,num_workers=2)

  def test_dataloader(self):
    return DataLoader(self.cifar_test,batch_size=self.batch_size,shuffle=False,num_workers=2)

# %%
class CIFAR10LitModel(pl.LightningModule):
    def __init__(
        self,
        input_shape,
        num_classes,
        learning_rate: float = 3e-4,
        optimizer_name: str = "adam",
        neurons_FC1: int = 512,
        neurons_FC2: int = 128,
        weight_decay: float = 1e-4,
        dropout: float = 0.0,
    ):
        super().__init__()
        self.save_hyperparameters()
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.learning_rate = learning_rate
        self.optimizer_name = optimizer_name
        self.weight_decay = weight_decay
        self.dropout = dropout

        # ----- model architecture (same convs as yours) -----
        self.conv1 = nn.Conv2d(3, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 32, 3, 1)
        self.conv3 = nn.Conv2d(32, 64, 3, 1)
        self.conv4 = nn.Conv2d(64, 64, 3, 1)
        self.pool1 = nn.MaxPool2d(2)
        self.pool2 = nn.MaxPool2d(2)

        n_sizes = self._get_output_shape(input_shape)
        self.fc1 = nn.Linear(n_sizes, neurons_FC1)
        self.fc2 = nn.Linear(neurons_FC1, neurons_FC2)
        self.fc3 = nn.Linear(neurons_FC2, num_classes)
        self.drop = nn.Dropout(self.dropout)

        self.train_acc = Accuracy(task='multiclass', num_classes=num_classes)
        self.val_acc   = Accuracy(task='multiclass', num_classes=num_classes)
        self.test_acc  = Accuracy(task='multiclass', num_classes=num_classes)

    def _get_output_shape(self, shape):
        with torch.no_grad():
            x = torch.rand(1, *shape, device=self.device if self.device else "cpu")
            x = self._feature_extractor(x)
            return x.view(1, -1).size(1)

    # conv1,relu, conv2,relu, maxpool, conv3,relu, conv4,relu, maxpool
    def _feature_extractor(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(F.relu(self.conv2(x)))
        x = F.relu(self.conv3(x))
        x = self.pool2(F.relu(self.conv4(x)))
        return x

    def forward(self, x):
        x = self._feature_extractor(x)
        x = x.view(x.size(0), -1)
        x = self.drop(F.relu(self.fc1(x)))
        x = self.drop(F.relu(self.fc2(x)))
        x = F.log_softmax(self.fc3(x), dim=1)
        return x

    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = F.nll_loss(logits, y)
        preds = torch.argmax(logits, dim=1)
        acc = self.train_acc(preds, y)
        self.log('train_loss', loss, on_step=True, on_epoch=True, logger=True)
        self.log('train_acc', acc,   on_step=True, on_epoch=True, logger=True)
        return loss

    def validation_step(self, batch, batch_idx):
      x, y = batch
      logits = self(x)
      loss = F.nll_loss(logits, y)
      preds = torch.argmax(logits, dim=1)
      acc = self.val_acc(preds, y)

      self.log("val_loss", loss, prog_bar=True, on_epoch=True, on_step=False)
      self.log("val_acc",  acc,  prog_bar=True, on_epoch=True, on_step=False)
      return loss



    def test_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = F.nll_loss(logits, y)
        preds = torch.argmax(logits, dim=1)
        acc = self.test_acc(preds, y)
        self.log('test_loss', loss, on_epoch=True)
        self.log('test_acc',  acc,  on_epoch=True)
        return loss

    def configure_optimizers(self):
      if self.optimizer_name.lower() == "adam":
        opt = torch.optim.Adam(
            self.parameters(),
            lr=self.learning_rate,
            weight_decay=self.weight_decay
        )
      elif self.optimizer_name.lower() == "sgd":
        opt = torch.optim.SGD(
            self.parameters(),
            lr=self.learning_rate,
            momentum=0.9,
            weight_decay=self.weight_decay
        )
      else:  # adamw
        opt = torch.optim.AdamW(
            self.parameters(),
            lr=self.learning_rate,
            weight_decay=self.weight_decay
        )
      return opt

# %%
# class for visualizing one batch of validation images along with predicted and rall class label
class ImagePredictionLogger(pl.Callback):
    def __init__(self, val_samples, num_samples=32):
        super().__init__()
        self.val_imgs, self.val_labels = val_samples
        self.val_imgs = self.val_imgs[:num_samples]
        self.val_labels = self.val_labels[:num_samples]

    def on_validation_epoch_end(self, trainer, pl_module):
        val_imgs = self.val_imgs.to(device=pl_module.device)
        logits = pl_module(val_imgs)
        preds = torch.argmax(logits, 1)

        trainer.logger.experiment.log({
            "examples": [wandb.Image(x, caption=f"Pred:{pred}, Label:{y}")
                            for x, pred, y in zip(val_imgs, preds, self.val_labels)],
            "global_step": trainer.global_step
            })

# %%
# Instantiate the cifar and model
cifar = CifarDataModule(batch_size=32)
cifar.prepare_data()
cifar.setup()

# Grab samples to log predictions on
samples = next(iter(cifar.val_dataloader()))
# Out:
# 100%|██████████| 170M/170M [00:17<00:00, 9.84MB/s]

# %%
### WandB, you have have an account(if you don't, create one)
def train_model(learning_rate=1e-3):
    wandb.login(key='')
    config=wandb.config
    wandb_logger = WandbLogger(project='lastt', job_type='train', log_model="all")
    # instantiate classes
    dm = CifarDataModule(32)
    dm.prepare_data()
    dm.setup()
    model = CIFAR10LitModel((3, 32, 32), dm.num_classes, learning_rate)
    wandb_logger.watch(model)
    # Initialize Callbacks
    checkpoint_callback = pl.callbacks.ModelCheckpoint()
    early_stop_callback = pl.callbacks.EarlyStopping(monitor="val_acc", patience=3, verbose=False, mode="max")
    ### WandB
    trainer = pl.Trainer(max_epochs=5,
                     logger=wandb_logger,
                     callbacks=[checkpoint_callback, early_stop_callback,ImagePredictionLogger(samples)]
                    )
    # Train the model
    trainer.fit(model, dm)

    # Evaluate the model
    trainer.test(dataloaders=cifar.test_dataloader())
    # tell the WandB you have finished
    wandb.finish()

# %%
import wandb
sweep_id = "bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/by7n73bx"

# Launch 10 runs (≥10 as required)
wandb.agent(sweep_id, function=train_model, count=10)
# Out:
# wandb: Agent Starting Run: 87v97ktr with config:
# wandb: 	learning_rate: 0.0011255330070538611
# wandb: 	num_classes: 16
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Currently logged in as: bechahana (bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_173619-87v97ktr</code>
# Syncing run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/87v97ktr' target="_blank">azure-sweep-1</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/87v97ktr' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/87v97ktr</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# wandb: WARNING Data passed to `wandb.Image` should consist of values in the range [0, 255], image data will be normalized to this range, but behavior will be removed in a future version of wandb.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:149: `.test(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.test(ckpt_path='best')` to use the best model or `.test(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/87v97ktr/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/87v97ktr/checkpoints/epoch=4-step=7035.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7317000031471252     │
# │         test_loss         │    0.8089628219604492     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆█████</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▃▂▁▄▄▂▃▃▂▄▆▆▃▃▄▇▄▅▃▅▆▇▆▅▅▆▆▇▆█▇▅██▆▇▇█▅█</td></tr><tr><td>train_loss_epoch</td><td>█▅▃▂▁</td></tr><tr><td>train_loss_step</td><td>██▇▇█▄▆▅▄▅▃▆▃▃▄▃▃▄▄▅▂▄▁▃▄▂▃▂▃▂▁▃▃▅▁▁▃▂▂▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>val_acc</td><td>▁▄▆▇█</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.7317</td></tr><tr><td>test_loss</td><td>0.80896</td></tr><tr><td>train_acc_epoch</td><td>0.76849</td></tr><tr><td>train_acc_step</td><td>0.84375</td></tr><tr><td>train_loss_epoch</td><td>0.65585</td></tr><tr><td>train_loss_step</td><td>0.53275</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.738</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">azure-sweep-1</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/87v97ktr' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/87v97ktr</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_173619-87v97ktr/logs</code>
# wandb: Agent Starting Run: x0kswjwb with config:
# wandb: 	learning_rate: 0.0012907906768788785
# wandb: 	num_classes: 10
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_173841-x0kswjwb</code>
# Syncing run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/x0kswjwb' target="_blank">ancient-sweep-2</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/x0kswjwb' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/x0kswjwb</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/x0kswjwb/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/x0kswjwb/checkpoints/epoch=4-step=7035.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7318999767303467     │
# │         test_loss         │    0.7873244881629944     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▇▇▇▇▇▇▇▇▇█</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▁▂▃▃▄▂▄▅▆▅▅▄▃▅▄▅▄▇▅▆▆▆█▅▅▇▅▇▆▇▆█▇▇█▇██▇▇</td></tr><tr><td>train_loss_epoch</td><td>█▅▃▂▁</td></tr><tr><td>train_loss_step</td><td>█▅▆▄▄▅▄▄▅▄▅▄▃▄▃▄▃▃▃▂▃▄▂▃▃▂▃▃▂▂▃▃▃▃▃▁▁▂▂▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>val_acc</td><td>▁▅▇██</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.7319</td></tr><tr><td>test_loss</td><td>0.78732</td></tr><tr><td>train_acc_epoch</td><td>0.79011</td></tr><tr><td>train_acc_step</td><td>0.71875</td></tr><tr><td>train_loss_epoch</td><td>0.59525</td></tr><tr><td>train_loss_step</td><td>0.82191</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.732</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ancient-sweep-2</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/x0kswjwb' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/x0kswjwb</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_173841-x0kswjwb/logs</code>
# wandb: Agent Starting Run: v9w9mng5 with config:
# wandb: 	learning_rate: 0.0005555284561273403
# wandb: 	num_classes: 15
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_174052-v9w9mng5</code>
# Syncing run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/v9w9mng5' target="_blank">worthy-sweep-3</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/v9w9mng5' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/v9w9mng5</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/v9w9mng5/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/v9w9mng5/checkpoints/epoch=4-step=7035.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7278000116348267     │
# │         test_loss         │     0.799966037273407     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆████████</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▂▁▃▁▄▄▄▄▃▆▃▄▃▃▄▆▆▅█▆▆▇▅▆▇▅▇▆▇▆▇█▆▆▆▇▇▇▇▆</td></tr><tr><td>train_loss_epoch</td><td>█▄▃▂▁</td></tr><tr><td>train_loss_step</td><td>██▇▆▆▅▄▅▅▅▅▄▄▄▄▆▄▃▄▂▃▂▂▂▂▂▃▂▃▂▁▁▂▂▂▁▃▃▃▃</td></tr><tr><td>trainer/global_step</td><td>▁▁▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>val_acc</td><td>▁▄▇▇█</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.7278</td></tr><tr><td>test_loss</td><td>0.79997</td></tr><tr><td>train_acc_epoch</td><td>0.76367</td></tr><tr><td>train_acc_step</td><td>0.65625</td></tr><tr><td>train_loss_epoch</td><td>0.67584</td></tr><tr><td>train_loss_step</td><td>0.93258</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.7286</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">worthy-sweep-3</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/v9w9mng5' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/v9w9mng5</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_174052-v9w9mng5/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: c5uhrov2 with config:
# wandb: 	learning_rate: 0.0016697477167506066
# wandb: 	num_classes: 16
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_174313-c5uhrov2</code>
# Syncing run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/c5uhrov2' target="_blank">swift-sweep-4</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/c5uhrov2' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/c5uhrov2</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/c5uhrov2/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/c5uhrov2/checkpoints/epoch=4-step=7035.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7232000231742859     │
# │         test_loss         │    0.8191819787025452     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆█████████</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▂▁▂▅▃▄▄▄▆▆▇▆▃▆▇▅▇▆▅▆▆▆▇▇▆██▇▆██▆▆█▇▇▇▇▇▇</td></tr><tr><td>train_loss_epoch</td><td>█▄▃▂▁</td></tr><tr><td>train_loss_step</td><td>█▇▆▆▅▅▅▄▅▄▅▄▄▃▃▃▃▃▃▄▂▂▂▂▃▁▁▂▃▂▂▂▂▂▂▂▂▃▃▃</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇█████</td></tr><tr><td>val_acc</td><td>▁▅▆▇█</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.7232</td></tr><tr><td>test_loss</td><td>0.81918</td></tr><tr><td>train_acc_epoch</td><td>0.76758</td></tr><tr><td>train_acc_step</td><td>0.71875</td></tr><tr><td>train_loss_epoch</td><td>0.66527</td></tr><tr><td>train_loss_step</td><td>0.80566</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.732</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">swift-sweep-4</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/c5uhrov2' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/c5uhrov2</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_174313-c5uhrov2/logs</code>
# wandb: Agent Starting Run: 77q16w6o with config:
# wandb: 	learning_rate: 0.0006519399046860853
# wandb: 	num_classes: 10
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_174526-77q16w6o</code>
# Syncing run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/77q16w6o' target="_blank">lunar-sweep-5</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/77q16w6o' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/77q16w6o</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/77q16w6o/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/77q16w6o/checkpoints/epoch=4-step=7035.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │     0.722599983215332     │
# │         test_loss         │    0.8074768781661987     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆███████</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▁▃▂▃▄▅▄▄▃▄▄▄▅▅▅▆▆▃▆▅▇▆█▇▇▆▆▇▄▆█▇█▇██▇▇▇█</td></tr><tr><td>train_loss_epoch</td><td>█▅▃▂▁</td></tr><tr><td>train_loss_step</td><td>█▇▆▇▆▆▆▆▄▄▄▆▆▇▅▅▃▆▅▃▃▄▃▄▃▃▃▂▁▄▂▂▂▃▁▂▃▁▂▄</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>val_acc</td><td>▁▅▇▇█</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.7226</td></tr><tr><td>test_loss</td><td>0.80748</td></tr><tr><td>train_acc_epoch</td><td>0.7748</td></tr><tr><td>train_acc_step</td><td>0.78125</td></tr><tr><td>train_loss_epoch</td><td>0.63834</td></tr><tr><td>train_loss_step</td><td>0.69115</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.7366</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lunar-sweep-5</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/77q16w6o' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/77q16w6o</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_174526-77q16w6o/logs</code>
# wandb: Agent Starting Run: imuznufb with config:
# wandb: 	learning_rate: 0.0008071491957651925
# wandb: 	num_classes: 19
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_174737-imuznufb</code>
# Syncing run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/imuznufb' target="_blank">serene-sweep-6</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/imuznufb' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/imuznufb</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/imuznufb/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/imuznufb/checkpoints/epoch=4-step=7035.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7390000224113464     │
# │         test_loss         │    0.7847927808761597     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆████████</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▁▅▄▄▃▅▅▅▅▅▅▅▅▅▆▅▅▅▆▅▅▅▇▇▇▇▇▇█▇█▅█▆▆▇▇▇█▇</td></tr><tr><td>train_loss_epoch</td><td>█▄▃▂▁</td></tr><tr><td>train_loss_step</td><td>█▆▆▄▅▄▅▅▄▄▃▃▃▃▄▃▅▃▃▃▂▃▂▃▃▂▃▁▂▃▂▂▂▃▂▂▃▁▃▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>val_acc</td><td>▁▄▇██</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.739</td></tr><tr><td>test_loss</td><td>0.78479</td></tr><tr><td>train_acc_epoch</td><td>0.78051</td></tr><tr><td>train_acc_step</td><td>0.78125</td></tr><tr><td>train_loss_epoch</td><td>0.62658</td></tr><tr><td>train_loss_step</td><td>0.54455</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.7188</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">serene-sweep-6</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/imuznufb' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/imuznufb</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_174737-imuznufb/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 46ymv0og with config:
# wandb: 	learning_rate: 0.0013325092793969931
# wandb: 	num_classes: 7
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_175018-46ymv0og</code>
# Syncing run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/46ymv0og' target="_blank">different-sweep-7</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/46ymv0og' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/46ymv0og</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/46ymv0og/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# ...
#  View run <strong style="color:#cdcd00">light-sweep-8</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/6tduip0i' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/6tduip0i</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_175232-6tduip0i/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ivex52nf with config:
# wandb: 	learning_rate: 0.0006567181366839443
# wandb: 	num_classes: 11
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_175453-ivex52nf</code>
# Syncing run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/ivex52nf' target="_blank">distinctive-sweep-9</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/ivex52nf' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/ivex52nf</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/ivex52nf/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/ivex52nf/checkpoints/epoch=4-step=7035.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7342000007629395     │
# │         test_loss         │     0.773305356502533     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▅▅▅▅▅▅▅▅▆▆▆▆▆██████████</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▁▃▄▃▄▄▄▆▄▅▅▆▃▆▅▃▅▆▆▅▆▄▆▇▅▆▆▆▆▇▆▇▇▆▅▆▇▆█▇</td></tr><tr><td>train_loss_epoch</td><td>█▅▃▂▁</td></tr><tr><td>train_loss_step</td><td>█▇▆▄▄▆▄▅▃▃▃▄▂▃▂▁▃▃▄▄▄▂▂▂▂▁▂▂▁▁▁▁▂▂▁▃▂▂▃▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>val_acc</td><td>▁▄▅▇█</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.7342</td></tr><tr><td>test_loss</td><td>0.77331</td></tr><tr><td>train_acc_epoch</td><td>0.76942</td></tr><tr><td>train_acc_step</td><td>0.65625</td></tr><tr><td>train_loss_epoch</td><td>0.65994</td></tr><tr><td>train_loss_step</td><td>0.76727</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.7434</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">distinctive-sweep-9</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/ivex52nf' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/ivex52nf</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_175453-ivex52nf/logs</code>
# wandb: Agent Starting Run: 2thgmzui with config:
# wandb: 	learning_rate: 0.0018883546415232183
# wandb: 	num_classes: 14
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_175711-2thgmzui</code>
# Syncing run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui' target="_blank">crisp-sweep-10</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/2thgmzui/checkpoints/epoch=4-step=7035.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/2thgmzui/checkpoints/epoch=4-step=7035.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7337999939918518     │
# │         test_loss         │    0.7778095006942749     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▆▆▆▆▆▆▆███████</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▁▃▃▂▆▄▄▅▄▃▄▇▆▆▄▆▄▇▄▅▆▆▇█▆▆▅▇▇▇▆█▇█▇▇▇▇▆▇</td></tr><tr><td>train_loss_epoch</td><td>█▅▃▂▁</td></tr><tr><td>train_loss_step</td><td>█▇▄▅▇▇▅▆▇▃▄▅▆▄▄▅▅▅▄▄▃▄▃▄▄▂▄▄▂▂▃▃▃▂▂▂▂▂▄▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>val_acc</td><td>▁▅▇██</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.7338</td></tr><tr><td>test_loss</td><td>0.77781</td></tr><tr><td>train_acc_epoch</td><td>0.76696</td></tr><tr><td>train_acc_step</td><td>0.875</td></tr><tr><td>train_loss_epoch</td><td>0.65857</td></tr><tr><td>train_loss_step</td><td>0.39668</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.7342</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">crisp-sweep-10</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_175711-2thgmzui/logs</code>

# %%
# Start training the model
train_model()
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Ignoring project 'lastt' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251021_175933-2thgmzui</code>
# Resuming run <strong><a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui' target="_blank">crisp-sweep-10</a></strong> to <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View project at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a>
#  View sweep at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/sweeps/by7n73bx</a>
#  View run at <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:751: Checkpoint directory ./lastt/2thgmzui/checkpoints exists and is not empty.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#    | Name      | Type               | Params | Mode
# ----------------------------------------------------------
# 0  | conv1     | Conv2d             | 896    | train
# 1  | conv2     | Conv2d             | 9.2 K  | train
# 2  | conv3     | Conv2d             | 18.5 K | train
# 3  | conv4     | Conv2d             | 36.9 K | train
# 4  | pool1     | MaxPool2d          | 0      | train
# 5  | pool2     | MaxPool2d          | 0      | train
# 6  | fc1       | Linear             | 819 K  | train
# 7  | fc2       | Linear             | 65.7 K | train
# 8  | fc3       | Linear             | 1.3 K  | train
# 9  | drop      | Dropout            | 0      | train
# 10 | train_acc | MulticlassAccuracy | 0      | train
# 11 | val_acc   | MulticlassAccuracy | 0      | train
# 12 | test_acc  | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 952 K     Trainable params
# 0         Non-trainable params
# 952 K     Total params
# 3.809     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at ./lastt/2thgmzui/checkpoints/epoch=4-step=7035-v1.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: WARNING Config item 'num_classes' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at ./lastt/2thgmzui/checkpoints/epoch=4-step=7035-v1.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7408999800682068     │
# │         test_loss         │    0.7793183922767639     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆████████</td></tr><tr><td>global_step</td><td>▁▂▄▅▇█</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc_epoch</td><td>▁▅▆▇█</td></tr><tr><td>train_acc_step</td><td>▁▃▃▃▃▂▅▅▅▄▅▆▆▅▄▆▇▅██▆▆▇▇▆▆▇▆▅▆▇▇█▇▅▇▆▇█▅</td></tr><tr><td>train_loss_epoch</td><td>█▄▃▂▁</td></tr><tr><td>train_loss_step</td><td>█▆▆▆▆▅▄▅▅▅▄▃▄▃▃▂▃▃▃▅▃▃▅▃▂▃▄▃▂▂▁▁▂▃▂▁▂▁▄▃</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>val_acc</td><td>▁▅▆▇█</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>global_step</td><td>7035</td></tr><tr><td>test_acc</td><td>0.7409</td></tr><tr><td>test_loss</td><td>0.77932</td></tr><tr><td>train_acc_epoch</td><td>0.78242</td></tr><tr><td>train_acc_step</td><td>0.6875</td></tr><tr><td>train_loss_epoch</td><td>0.61811</td></tr><tr><td>train_loss_step</td><td>0.80352</td></tr><tr><td>trainer/global_step</td><td>7035</td></tr><tr><td>val_acc</td><td>0.7442</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">crisp-sweep-10</strong> at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt/runs/2thgmzui</a><br> View project at: <a href='https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt' target="_blank">https://wandb.ai/bechahana-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/lastt</a><br>Synced 5 W&B file(s), 193 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251021_175933-2thgmzui/logs</code>

# %%
### TASK OF THE STUDENT

# extend WandB.ai integration in the code with sweeps
# (e.g. add variables like learning rate, optimizer, neurons_FC1, neurons_FC2)
# help: https://docs.wandb.ai/guides/sweeps and
#       https://github.com/wandb/wandb/issues/5003
# store the hyperparameters and val_acc to wandb
# run at least 10 trainings
# in wandb.ai, export the result of the runs as a .csv file,
# in wandb.ai, create a report from the sweep results and share it by submitting
# the link in Moodle.
